# %%
import pandas as pd
import seaborn as sns

raw_data = pd.read_csv('Air_Quality_and_Health_Impacts_20260715.csv')
raw_data
# Out:
#        Unique ID Indicator ID                                         Name  \
# 0         979194        1,427                      Fine particles (PM 2.5)
# 1         980097        1,431                       Nitrogen dioxide (NO2)
# 2         980098        1,431                       Nitrogen dioxide (NO2)
# 3         980099        1,431                       Nitrogen dioxide (NO2)
# 4         980100        1,431                       Nitrogen dioxide (NO2)
# ...          ...          ...                                          ...
# 19822     131017          652  Cardiac and respiratory deaths due to Ozone
# 19823     131016          652  Cardiac and respiratory deaths due to Ozone
# 19824     131015          652  Cardiac and respiratory deaths due to Ozone
# 19825     131014          652  Cardiac and respiratory deaths due to Ozone
# 19826     131013          652  Cardiac and respiratory deaths due to Ozone
#
#                      Measure Measure Info Geo Type Name  Geo Join ID  \
# 0                Winter mean       mcg/m3         UHF34          104
# 1                Annual mean          ppb         UHF34          304
# 2                Annual mean          ppb         UHF34          303
# 3                Annual mean          ppb         UHF34          302
# 4                Annual mean          ppb         UHF34          301
# ...                      ...          ...           ...          ...
# 19822  Estimated annual rate  per 100,000         UHF42          501
# 19823  Estimated annual rate  per 100,000         UHF42          410
# 19824  Estimated annual rate  per 100,000         UHF42          409
# 19825  Estimated annual rate  per 100,000         UHF42          408
# 19826  Estimated annual rate  per 100,000         UHF42          407
#
#                              Geo Place Name Time Period  Start_Date  \
# 0                      Pelham - Throgs Neck        2024  01/01/2024
# 1                           Upper West Side        2024  01/01/2024
# 2                               East Harlem        2024  01/01/2024
# 3      Central Harlem - Morningside Heights        2024  01/01/2024
# 4                        Washington Heights        2024  01/01/2024
# ...                                     ...         ...         ...
# 19822                         Port Richmond   2005-2007  01/01/2005
# 19823                             Rockaways   2005-2007  01/01/2005
# 19824                      Southeast Queens   2005-2007  01/01/2005
# 19825                               Jamaica   2005-2007  01/01/2005
# 19826                      Southwest Queens   2005-2007  01/01/2005
#
#        Data Value  Message
# 0        5.834572      NaN
# 1       18.288730      NaN
# 2       16.184849      NaN
# 3       16.521823      NaN
# 4       16.264552      NaN
# ...           ...      ...
# 19822    5.600000      NaN
# 19823   11.700000      NaN
# 19824    4.300000      NaN
# 19825    5.500000      NaN
# 19826    3.900000      NaN
#
# [19827 rows x 12 columns]

# %%
#Initial Questions

- Which borough has the highest air quality? 
- Why some boroughs have better air quality than other ones?
# Out:
#   Cell In[12], line 3
#     - Which borough has the highest air quality?
#             ^
# SyntaxError: invalid syntax

# %%
time_to_close = raw_data[['Boro','RptDate','RptClosed']]
time_to_close

# %%
print(raw_data.nunique())

# %%
raw_data["Measure"].unique()

# %%
raw_data["Measure Info"].unique()

# %%
##We have to make sure that we are talking about 5 boroughs, to make the data cleare

# %%
##new_table = raw_data[['Boro','RptDate','RptClosed']]
new_table =

# %%
#TRANSFORMING GEO JOIN ID INTO 5 BOROUGHS, TO HAVE MORE CLARITY. 

raw_data.dtypes

# %%
# Create a dictionary mapping the first digit of the Geo Join ID to the boroughs
borough_map = {
    '1': 'Bronx',
    '2': 'Brooklyn',
    '3': 'Manhattan',
    '4': 'Queens',
    '5': 'Staten Island'
}
raw_data['Borough'] = raw_data['Geo Join ID'].astype(str).str[0].map(borough_map)

# Preview the changes
raw_data[['Geo Join ID', 'Borough']].head()
# Out:
#    Geo Join ID    Borough
# 0          104      Bronx
# 1          304  Manhattan
# 2          303  Manhattan
# 3          302  Manhattan
# 4          301  Manhattan

# %%
# 1. Map the boroughs first (since cell 11 was re-run)
borough_map = {
    '1': 'Bronx',
    '2': 'Brooklyn',
    '3': 'Manhattan',
    '4': 'Queens',
    '5': 'Staten Island'
}
raw_data['Borough'] = raw_data['Geo Join ID'].astype(str).str[0].map(borough_map)

# 2. Select your specific columns into a new DataFrame
# Note: You should also include 'Data Value' so you can analyze the numbers later!
columns_to_keep = ['Borough', 'Name', 'Measure', 'Measure Info', 'Start_Date', 'Time Period', 'Data Value']
borough_table = raw_data[columns_to_keep]

# 3. Preview your new clean table
borough_table.head()
# Out:
#      Borough                     Name      Measure Measure Info  Start_Date  \
# 0      Bronx  Fine particles (PM 2.5)  Winter mean       mcg/m3  01/01/2024
# 1  Manhattan   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024
# 2  Manhattan   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024
# 3  Manhattan   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024
# 4  Manhattan   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024
#
#   Time Period  Data Value
# 0        2024    5.834572
# 1        2024   18.288730
# 2        2024   16.184849
# 3        2024   16.521823
# 4        2024   16.264552

# %%
# Keep only geo types where a single leading-digit rule correctly gives one borough
valid_types = ['UHF34', 'UHF42', 'Borough']
clean_data = raw_data[raw_data['Geo Type Name'].isin(valid_types)].copy()

borough_map = {
    '1': 'Bronx',
    '2': 'Brooklyn',
    '3': 'Manhattan',
    '4': 'Queens',
    '5': 'Staten Island'
}
clean_data['Borough'] = clean_data['Geo Join ID'].astype(str).str[0].map(borough_map)

columns_to_keep = ['Name', 'Measure', 'Measure Info', 'Start_Date', 'Time Period', 'Borough']
new_table = clean_data[columns_to_keep]
new_table.head()
# Out:
#                       Name      Measure Measure Info  Start_Date Time Period  \
# 0  Fine particles (PM 2.5)  Winter mean       mcg/m3  01/01/2024        2024
# 1   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024        2024
# 2   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024        2024
# 3   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024        2024
# 4   Nitrogen dioxide (NO2)  Annual mean          ppb  01/01/2024        2024
#
#      Borough
# 0      Bronx
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
new_table.shape        # (rows, columns) — tells you how many rows survived filtering
# Out:
# (12388, 6)

# %%
new_table['Borough'].value_counts()   # rows per borough — good sanity check
# Out:
# Borough
# Brooklyn         3427
# Queens           3018
# Manhattan        2790
# Bronx            2019
# Staten Island    1134
# Name: count, dtype: int64

# %%
columns_to_keep = ['Name', 'Measure', 'Measure Info', 'Start_Date', 'Time Period', 'Borough', 'Data Value']
new_table = clean_data[columns_to_keep].copy()

new_table['Data Value'] = pd.to_numeric(new_table['Data Value'], errors='coerce')
new_table['Start_Date'] = pd.to_datetime(new_table['Start_Date'], format='%m/%d/%Y')

new_table.dtypes
# Out:
# Name                       str
# Measure                    str
# Measure Info               str
# Start_Date      datetime64[us]
# Time Period                str
# Borough                    str
# Data Value             float64
# dtype: object

# %%
# Step 1: extract the end year from Time Period
def get_end_year(period):
    period = str(period)
    if '-' in period:
        return int(period.split('-')[1])
    else:
        return int(period)

new_table['End_Year'] = new_table['Time Period'].apply(get_end_year)

# Step 2: turn that end year into an actual date (Dec 31 of that year)
new_table['End_Date'] = pd.to_datetime(new_table['End_Year'].astype(str) + '-12-31')

# Step 3: now you can subtract
new_table['Period_Duration'] = new_table['End_Date'] - new_table['Start_Date']

new_table[['Start_Date', 'Time Period', 'End_Date', 'Period_Duration']].head()
# Out:
#   Start_Date Time Period   End_Date Period_Duration
# 0 2024-01-01        2024 2024-12-31        365 days
# 1 2024-01-01        2024 2024-12-31        365 days
# 2 2024-01-01        2024 2024-12-31        365 days
# 3 2024-01-01        2024 2024-12-31        365 days
# 4 2024-01-01        2024 2024-12-31        365 days

# %%
new_table['Period_Duration_Days'] = new_table['Period_Duration'].dt.days
new_table['Period_Duration_Years'] = (new_table['Period_Duration_Days'] / 365.25).round(1)
new_table
# Out:
#                                               Name                Measure  \
# 0                          Fine particles (PM 2.5)            Winter mean
# 1                           Nitrogen dioxide (NO2)            Annual mean
# 2                           Nitrogen dioxide (NO2)            Annual mean
# 3                           Nitrogen dioxide (NO2)            Annual mean
# 4                           Nitrogen dioxide (NO2)            Annual mean
# ...                                            ...                    ...
# 19822  Cardiac and respiratory deaths due to Ozone  Estimated annual rate
# 19823  Cardiac and respiratory deaths due to Ozone  Estimated annual rate
# 19824  Cardiac and respiratory deaths due to Ozone  Estimated annual rate
# 19825  Cardiac and respiratory deaths due to Ozone  Estimated annual rate
# 19826  Cardiac and respiratory deaths due to Ozone  Estimated annual rate
#
#       Measure Info Start_Date Time Period        Borough  Data Value  \
# 0           mcg/m3 2024-01-01        2024          Bronx    5.834572
# 1              ppb 2024-01-01        2024      Manhattan   18.288730
# 2              ppb 2024-01-01        2024      Manhattan   16.184849
# 3              ppb 2024-01-01        2024      Manhattan   16.521823
# 4              ppb 2024-01-01        2024      Manhattan   16.264552
# ...            ...        ...         ...            ...         ...
# 19822  per 100,000 2005-01-01   2005-2007  Staten Island    5.600000
# 19823  per 100,000 2005-01-01   2005-2007         Queens   11.700000
# 19824  per 100,000 2005-01-01   2005-2007         Queens    4.300000
# 19825  per 100,000 2005-01-01   2005-2007         Queens    5.500000
# 19826  per 100,000 2005-01-01   2005-2007         Queens    3.900000
#
#        End_Year   End_Date Period_Duration  Period_Duration_Days  \
# 0          2024 2024-12-31        365 days                   365
# 1          2024 2024-12-31        365 days                   365
# 2          2024 2024-12-31        365 days                   365
# 3          2024 2024-12-31        365 days                   365
# 4          2024 2024-12-31        365 days                   365
# ...         ...        ...             ...                   ...
# 19822      2007 2007-12-31       1094 days                  1094
# 19823      2007 2007-12-31       1094 days                  1094
# 19824      2007 2007-12-31       1094 days                  1094
# 19825      2007 2007-12-31       1094 days                  1094
# 19826      2007 2007-12-31       1094 days                  1094
#
#        Period_Duration_Years
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
# ...                      ...
# 19822                    3.0
# 19823                    3.0
# 19824                    3.0
# 19825                    3.0
# 19826                    3.0
#
# [12388 rows x 12 columns]
